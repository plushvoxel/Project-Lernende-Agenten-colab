# %% [markdown]
# [View in Colaboratory](https://colab.research.google.com/github/plushvoxel/Project-Lernende-Agenten-colab/blob/master/upload_test.ipynb)

# %%
from google.colab import files

uploaded = files.upload()

for fn in uploaded.keys():
  print('User uploaded file "{name}" with length {length} bytes'.format(name=fn, length=len(uploaded[fn])))

# %%
from os import listdir
listdir()
# Out:
# ['.config',
#  'sample_data',
#  'fm_img4dzyr.iq',
#  'fm_q8kwkexb.iq',
#  'am_qr00tca3.iq',
#  'fm_5n9e_q43.iq',
#  'am_a_y82o6k.iq',
#  'fm_pnb87dm_.iq',
#  'am_d01uiawe.iq',
#  'am_lx1bnu9p.iq',
#  'am_0ppqe3ur.iq',
#  'am_jo235k0p.iq',
#  'am_c82gr7ip.iq',
#  'am_ea9pb93h.iq',
#  'am_fqki5eo9.iq',
#  'am_ehts5fdj.iq',
#  'fm_2ixtdj_n.iq',
#  'am_kaps03g4.iq',
#  'fm_o6e7rc_o.iq',
#  'fm_3i0aknuu.iq',
#  'am_n8dfla71.iq',
#  'fm_y234atfy.iq',
#  'am_y3n78w8u.iq',
#  'fm__batds_w.iq',
#  'fm_fv3wtu90.iq',
#  'fm_zych334v.iq',
#  'fm_u8pzgov3.iq',
#  'am_4du11eap.iq',
#  'am_7pe9341v.iq',
#  'am_s__op5q5.iq',
#  'am_uxwu9kg0.iq',
#  'fm_9gfiy0r9.iq',
#  'am_ufqfr7fo.iq',
#  'am_i2rz5s0l.iq',
#  'am_agkjpmjf.iq',
#  'am_2rs5s1h3.iq',
#  'am_uy1rgxow.iq',
#  'am_2fee4rsz.iq',
#  'am_jmvc8vff.iq',
#  'am_4bh11wnc.iq',
#  'fm_358o5fr_.iq',
#  'fm_il7eprgo.iq',
#  'am_xoa638dz.iq',
#  'am_i__8bcdi.iq',
#  'fm_0zux1m3w.iq',
#  'fm_gp89c7ro.iq',
#  'am_yq1z9jdk.iq',
#  'fm_jw7x3fav.iq',
#  'fm_t6cgyzhg.iq',
#  'fm_yplhcovd.iq',
#  'fm_f__f0k5a.iq',
#  'am_wkq1c09h.iq',
#  'fm_fnp6kr8g.iq',
#  'am_iaepb7qp.iq',
#  'fm_25_ibxuu.iq',
#  'am_169bne_0.iq',
#  'fm_yopswnsq.iq',
#  'am_xmby2hnc.iq',
#  'am__2khlph5.iq',
#  'am_o5xayw9b.iq',
#  'am_nfaqsldx.iq',
#  'fm_f4nebr1q.iq',
#  'fm_9dkftt80.iq',
#  'am_167msu43.iq',
#  'am_nxaovedt.iq',
#  'am_4ce1057i.iq',
#  'am_24qc2h4n.iq',
#  'am_5m3fcf_4.iq',
#  'fm_8lumph2r.iq',
#  'am__p6dr9z_.iq',
#  'am_tlsl5tk2.iq',
#  'fm_5_urbrhk.iq',
#  'am_hvicfg_0.iq',
#  'fm_62vxipvu.iq',
#  'fm_0xvqmjwn.iq',
#  'am_j2hgjjfi.iq',
#  'fm_79cx791x.iq',
#  'fm_jorxmeh9.iq',
#  'am_n147j_yq.iq',
#  'am_ebvmgjnp.iq',
#  'fm_wv6z4yk2.iq',
#  'am_19hmg71t.iq',
#  'fm_he6rmw4x.iq',
#  'am_g5ixacgu.iq',
#  'fm_5lz1f04l.iq',
#  'am_2vfespib.iq',
#  'fm_yz90npuy.iq',
#  'fm_hnrtc58j.iq',
#  'fm_even04eb.iq',
#  'fm_vj78z6e1.iq',
#  'fm_rfqjozvk.iq',
#  'fm_40z38a4u.iq',
#  'am_gxqsrrjw.iq',
#  'fm_lucyaq4d.iq',
#  'am_u039l6q9.iq',
#  'fm_pytmww_1.iq',
#  'am_dkuw054u.iq',
#  'fm_0xumdqxe.iq',
#  'fm_78s5x6_5.iq',
#  'fm_k1n6izpv.iq',
#  'fm_kxcbhxw2.iq',
#  'am_v480lf4e.iq',
#  'fm_k9ssuzb3.iq',
#  'am_l1ckru0m.iq',
#  'fm_yikgy88q.iq',
#  'fm_3jsu00ac.iq',
#  'fm_4pmjo28x.iq',
#  'am_ogltpt2f.iq',
#  'fm_f0a28yl4.iq',
#  'am_rzii0wlq.iq',
#  'fm_y1mjncxt.iq',
#  'fm_ljn1psty.iq',
#  'fm_ez5hdlxl.iq',
#  'am_d0zzslkv.iq',
#  'fm_askhjwta.iq',
#  'fm_5ddfnr6z.iq',
#  'am_ycd2gcjo.iq',
#  'fm_qb9usigo.iq',
#  'fm_wqf6v__a.iq',
#  'fm_uftev2an.iq',
#  'fm_o0j3jsx6.iq',
#  'fm_jqy3ku5f.iq',
#  'fm_mxc67c5j.iq',
#  'am_38d6nsd2.iq',
#  'am_rqbp2mgb.iq',
#  'am_pq58_0sd.iq',
#  'am_cu4cqwoy.iq',
#  'am_yar_im3d.iq',
#  'am_pgta49ks.iq',
#  'am_sjx9z976.iq',
#  'fm_k04087dk.iq',
#  'am_0mh9z1uf.iq',
#  'am_754jxsyu.iq',
#  'am_aaltk_nb.iq',
#  'fm_hmm1vqn_.iq',
#  'am_5y7ir5zq.iq',
#  'am_jd3rru55.iq',
#  'fm_3g3js0hh.iq',
#  'am_3oaztbwn.iq',
#  'am_s4v9ss9d.iq',
#  'fm_z5bdopmu.iq',
#  'am_84xt9ucy.iq',
#  'am_t6u7h_jp.iq',
#  'am_74ljhech.iq',
#  'fm_pyf4grbc.iq',
#  'fm_231k_dnc.iq',
#  'fm_ct3884ig.iq',
#  'fm_ud2dtthk.iq',
#  'am_nepdnh3n.iq',
#  'fm_ypwsvotg.iq',
#  'fm_9yhy0173.iq',
#  'am_03ey1a2i.iq',
#  'am__32_u5zt.iq',
#  'am_p0eswrpz.iq',
#  'am_lms2fp0j.iq',
#  'fm_esejnqp_.iq',
#  'am_sq3bbmy2.iq',
#  'fm_hus6j6i6.iq',
#  'fm_05bmsvl0.iq',
#  'am_omt8j15_.iq',
#  'am_w8uqcy22.iq',
#  'am_h1fhhymt.iq',
#  'am_ze9lmdob.iq',
#  'am_u488w01e.iq',
#  'fm_ogxq7tk3.iq',
#  'fm_9zyj3c6d.iq',
#  'fm_hb9ygql8.iq',
#  'am_yodo5p00.iq',
#  'fm_82iad5aw.iq',
#  'am_5s85mn8f.iq',
#  'am_h0cryz7k.iq',
#  'am_gwslbjoe.iq',
#  'fm_mjw1cgxh.iq',
#  'am_ad0n_6k8.iq',
#  'fm_xtaxak2w.iq',
#  'am_7m3839eq.iq',
#  'am_p27xtn0k.iq',
#  'am_0dyoui02 (1).iq',
#  'fm_4ey5jmoy.iq',
#  'am_qpkvxigi.iq',
#  'am_q93qr19b.iq',
#  'fm_83zqhwqf.iq',
#  'fm_8trangza.iq',
#  'am_8_vaayuy.iq',
#  'fm_7wt02qks.iq',
#  'fm_01s66yuy.iq',
#  'fm_z7rtjnk7.iq',
#  'fm__50gdlki.iq',
#  'fm_amtfzk9g.iq',
#  'am_w2jwd2fo.iq',
#  'fm_13w78nyb.iq',
#  'am_o0xkci3m.iq',
#  'am_7jmp2wzq.iq',
#  'fm_p00awmw8.iq',
#  'fm_nfqm5qmk.iq',
#  'fm_5c1jcib9.iq',
#  'fm_c5nyh2y8.iq',
#  'fm__ep7wwof.iq',
#  'fm_6zy7e50c.iq',
#  'fm_l22q2ohf.iq',
#  'am_6e769x9n.iq',
#  'fm_wrf4pfd7.iq',
#  'fm_hv9k0air.iq',
#  'fm_hu6l3urf.iq',
#  'fm_kjgvnrkt.iq',
#  'am_p02i94aa.iq',
#  'am_fnit3cf5.iq',
#  'am_9i0rrbie.iq',
#  'fm_qq81czml.iq',
#  'am_gp5utwci.iq',
#  'am_f4mvzmn6.iq',
#  'am_uax_zspq.iq',
#  'fm_s3dc8rju.iq',
#  'fm__u6ohlck.iq',
#  'am_fkjvd31r.iq',
#  'am_0dyoui02.iq',
#  'am_42ckrf9y.iq',
#  'am_zdhp5v3l.iq',
#  'fm_7g46qnxg.iq',
#  'fm_633ncib1.iq',
#  'fm_0lqd1i2e.iq',
#  'fm_t5sx3tal.iq',
#  'fm_lxulsj61.iq']
